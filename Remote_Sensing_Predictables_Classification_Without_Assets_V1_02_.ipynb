# %%
# Installs geemap package
# !pip install geemap
# !pip install ipygee
# !pip install geopandas
# !pip install js2py
# !pip install folium
# !pip install rasterio
# !pip install tslearn
# !pip install earthengine-api
# Out:
# Requirement already satisfied: geemap in /home/hubert/anaconda3/lib/python3.9/site-packages (0.10.1)
# Requirement already satisfied: sankee in /home/hubert/anaconda3/lib/python3.9/site-packages (from geemap) (0.0.7)
# Requirement already satisfied: mss in /home/hubert/anaconda3/lib/python3.9/site-packages (from geemap) (6.1.0)
# Requirement already satisfied: pyshp>=2.1.3 in /home/hubert/anaconda3/lib/python3.9/site-packages (from geemap) (2.1.3)
# Requirement already satisfied: geocoder in /home/hubert/anaconda3/lib/python3.9/site-packages (from geemap) (1.38.1)
# Requirement already satisfied: ipynb-py-convert in /home/hubert/anaconda3/lib/python3.9/site-packages (from geemap) (0.4.6)
# Requirement already satisfied: geojson in /home/hubert/anaconda3/lib/python3.9/site-packages (from geemap) (2.5.0)
# Requirement already satisfied: jupyterlab>=3 in /home/hubert/anaconda3/lib/python3.9/site-packages (from geemap) (3.2.1)
# Requirement already satisfied: ipytree in /home/hubert/anaconda3/lib/python3.9/site-packages (from geemap) (0.2.1)
# Requirement already satisfied: python-box in /home/hubert/anaconda3/lib/python3.9/site-packages (from geemap) (5.4.1)
# Requirement already satisfied: bqplot in /home/hubert/anaconda3/lib/python3.9/site-packages (from geemap) (0.12.31)
# Requirement already satisfied: ipyfilechooser>=0.6.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from geemap) (0.6.0)
# Requirement already satisfied: click in /home/hubert/anaconda3/lib/python3.9/site-packages (from geemap) (8.0.3)
# Requirement already satisfied: pillow in /home/hubert/anaconda3/lib/python3.9/site-packages (from geemap) (8.4.0)
# Requirement already satisfied: voila in /home/hubert/anaconda3/lib/python3.9/site-packages (from geemap) (0.3.0)
# Requirement already satisfied: geeadd>=0.5.1 in /home/hubert/anaconda3/lib/python3.9/site-packages (from geemap) (0.5.5)
# Requirement already satisfied: xyzservices in /home/hubert/anaconda3/lib/python3.9/site-packages (from geemap) (2021.11.0)
# Requirement already satisfied: earthengine-api>=0.1.230 in /home/hubert/anaconda3/lib/python3.9/site-packages (from geemap) (0.1.292)
# Requirement already satisfied: matplotlib in /home/hubert/anaconda3/lib/python3.9/site-packages (from geemap) (3.4.3)
# Requirement already satisfied: owslib in /home/hubert/anaconda3/lib/python3.9/site-packages (from geemap) (0.25.0)
# Requirement already satisfied: ffmpeg-python in /home/hubert/anaconda3/lib/python3.9/site-packages (from geemap) (0.2.0)
# Requirement already satisfied: ipyleaflet<=0.14.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from geemap) (0.14.0)
# Requirement already satisfied: colour in /home/hubert/anaconda3/lib/python3.9/site-packages (from geemap) (0.1.5)
# Requirement already satisfied: pandas in /home/hubert/anaconda3/lib/python3.9/site-packages (from geemap) (1.3.4)
# Requirement already satisfied: pycrs in /home/hubert/anaconda3/lib/python3.9/site-packages (from geemap) (1.0.2)
# Requirement already satisfied: palettable in /home/hubert/anaconda3/lib/python3.9/site-packages (from geemap) (3.3.0)
# Requirement already satisfied: googledrivedownloader in /home/hubert/anaconda3/lib/python3.9/site-packages (from geemap) (0.4)
# Requirement already satisfied: numpy in /home/hubert/anaconda3/lib/python3.9/site-packages (from geemap) (1.20.3)
# Requirement already satisfied: whiteboxgui>=0.6.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from geemap) (0.6.0)
# Requirement already satisfied: ipyevents in /home/hubert/anaconda3/lib/python3.9/site-packages (from geemap) (2.0.1)
# Requirement already satisfied: folium>=0.11.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from geemap) (0.12.1.post1)
# Requirement already satisfied: google-auth>=1.4.1 in /home/hubert/anaconda3/lib/python3.9/site-packages (from earthengine-api>=0.1.230->geemap) (1.35.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /home/hubert/anaconda3/lib/python3.9/site-packages (from earthengine-api>=0.1.230->geemap) (0.1.0)
# Requirement already satisfied: six in /home/hubert/anaconda3/lib/python3.9/site-packages (from earthengine-api>=0.1.230->geemap) (1.16.0)
# Requirement already satisfied: google-cloud-storage in /home/hubert/anaconda3/lib/python3.9/site-packages (from earthengine-api>=0.1.230->geemap) (1.43.0)
# Requirement already satisfied: google-api-python-client<2,>=1.12.1 in /home/hubert/anaconda3/lib/python3.9/site-packages (from earthengine-api>=0.1.230->geemap) (1.12.8)
# Requirement already satisfied: future in /home/hubert/anaconda3/lib/python3.9/site-packages (from earthengine-api>=0.1.230->geemap) (0.18.2)
# Requirement already satisfied: httplib2shim in /home/hubert/anaconda3/lib/python3.9/site-packages (from earthengine-api>=0.1.230->geemap) (0.0.3)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /home/hubert/anaconda3/lib/python3.9/site-packages (from earthengine-api>=0.1.230->geemap) (0.20.2)
# Requirement already satisfied: branca>=0.3.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from folium>=0.11.0->geemap) (0.4.2)
# Requirement already satisfied: jinja2>=2.9 in /home/hubert/anaconda3/lib/python3.9/site-packages (from folium>=0.11.0->geemap) (2.11.3)
# Requirement already satisfied: requests in /home/hubert/anaconda3/lib/python3.9/site-packages (from folium>=0.11.0->geemap) (2.26.0)
# Requirement already satisfied: logzero>=1.5.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from geeadd>=0.5.1->geemap) (1.7.0)
# Requirement already satisfied: beautifulsoup4>=4.9.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from geeadd>=0.5.1->geemap) (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in /home/hubert/anaconda3/lib/python3.9/site-packages (from beautifulsoup4>=4.9.0->geeadd>=0.5.1->geemap) (2.2.1)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.230->geemap) (3.0.1)
# Requirement already satisfied: google-api-core<2dev,>=1.21.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.230->geemap) (1.31.4)
# Requirement already satisfied: packaging>=14.3 in /home/hubert/anaconda3/lib/python3.9/site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.230->geemap) (21.0)
# Requirement already satisfied: setuptools>=40.3.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.230->geemap) (58.0.4)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.230->geemap) (1.54.0)
# Requirement already satisfied: protobuf>=3.12.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.230->geemap) (3.19.1)
# Requirement already satisfied: pytz in /home/hubert/anaconda3/lib/python3.9/site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.230->geemap) (2021.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/hubert/anaconda3/lib/python3.9/site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.230->geemap) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.230->geemap) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/hubert/anaconda3/lib/python3.9/site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.230->geemap) (4.8)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /home/hubert/anaconda3/lib/python3.9/site-packages (from httplib2<1dev,>=0.9.2->earthengine-api>=0.1.230->geemap) (3.0.4)
# Requirement already satisfied: ipywidgets in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipyfilechooser>=0.6.0->geemap) (7.6.5)
# Requirement already satisfied: traittypes<3,>=0.2.1 in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipyleaflet<=0.14.0->geemap) (0.2.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (6.4.1)
# Requirement already satisfied: traitlets>=4.3.1 in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.1.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.5.1)
# Requirement already satisfied: nbformat>=4.2.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.1.3)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.0)
# Requirement already satisfied: ipython>=4.0.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (7.29.0)
# Requirement already satisfied: jupyter-client<8.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (6.1.12)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.4.1)
# Requirement already satisfied: tornado<7.0,>=4.2 in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (6.1)
# Requirement already satisfied: decorator in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.1.0)
# Requirement already satisfied: pygments in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.10.0)
# Requirement already satisfied: backcall in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.20)
# Requirement already satisfied: jedi>=0.16 in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.18.0)
# Requirement already satisfied: pickleshare in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.7.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.8.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/hubert/anaconda3/lib/python3.9/site-packages (from jinja2>=2.9->folium>=0.11.0->geemap) (1.1.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.8.1)
# Requirement already satisfied: pyzmq>=13 in /home/hubert/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (22.2.1)
# Requirement already satisfied: python-dateutil>=2.1 in /home/hubert/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.8.2)
# Requirement already satisfied: jupyterlab-server~=2.3 in /home/hubert/anaconda3/lib/python3.9/site-packages (from jupyterlab>=3->geemap) (2.8.2)
# Requirement already satisfied: nbclassic~=0.2 in /home/hubert/anaconda3/lib/python3.9/site-packages (from jupyterlab>=3->geemap) (0.2.6)
# Requirement already satisfied: jupyter-server~=1.4 in /home/hubert/anaconda3/lib/python3.9/site-packages (from jupyterlab>=3->geemap) (1.4.1)
# Requirement already satisfied: prometheus-client in /home/hubert/anaconda3/lib/python3.9/site-packages (from jupyter-server~=1.4->jupyterlab>=3->geemap) (0.11.0)
# Requirement already satisfied: Send2Trash in /home/hubert/anaconda3/lib/python3.9/site-packages (from jupyter-server~=1.4->jupyterlab>=3->geemap) (1.8.0)
# Requirement already satisfied: anyio>=2.0.2 in /home/hubert/anaconda3/lib/python3.9/site-packages (from jupyter-server~=1.4->jupyterlab>=3->geemap) (2.2.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/hubert/anaconda3/lib/python3.9/site-packages (from jupyter-server~=1.4->jupyterlab>=3->geemap) (0.9.4)
# Requirement already satisfied: nbconvert in /home/hubert/anaconda3/lib/python3.9/site-packages (from jupyter-server~=1.4->jupyterlab>=3->geemap) (6.1.0)
# Requirement already satisfied: idna>=2.8 in /home/hubert/anaconda3/lib/python3.9/site-packages (from anyio>=2.0.2->jupyter-server~=1.4->jupyterlab>=3->geemap) (3.2)
# Requirement already satisfied: sniffio>=1.1 in /home/hubert/anaconda3/lib/python3.9/site-packages (from anyio>=2.0.2->jupyter-server~=1.4->jupyterlab>=3->geemap) (1.2.0)
# Requirement already satisfied: json5 in /home/hubert/anaconda3/lib/python3.9/site-packages (from jupyterlab-server~=2.3->jupyterlab>=3->geemap) (0.9.6)
# Requirement already satisfied: entrypoints>=0.2.2 in /home/hubert/anaconda3/lib/python3.9/site-packages (from jupyterlab-server~=2.3->jupyterlab>=3->geemap) (0.3)
# Requirement already satisfied: jsonschema>=3.0.1 in /home/hubert/anaconda3/lib/python3.9/site-packages (from jupyterlab-server~=2.3->jupyterlab>=3->geemap) (3.2.0)
# Requirement already satisfied: babel in /home/hubert/anaconda3/lib/python3.9/site-packages (from jupyterlab-server~=2.3->jupyterlab>=3->geemap) (2.9.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.3->jupyterlab>=3->geemap) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.3->jupyterlab>=3->geemap) (21.2.0)
# Requirement already satisfied: notebook<7 in /home/hubert/anaconda3/lib/python3.9/site-packages (from nbclassic~=0.2->jupyterlab>=3->geemap) (6.4.5)
# Requirement already satisfied: argon2-cffi in /home/hubert/anaconda3/lib/python3.9/site-packages (from notebook<7->nbclassic~=0.2->jupyterlab>=3->geemap) (20.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/hubert/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.7.0)
# Requirement already satisfied: wcwidth in /home/hubert/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.5)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/hubert/anaconda3/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api>=0.1.230->geemap) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/hubert/anaconda3/lib/python3.9/site-packages (from requests->folium>=0.11.0->geemap) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/hubert/anaconda3/lib/python3.9/site-packages (from requests->folium>=0.11.0->geemap) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from requests->folium>=0.11.0->geemap) (2.0.4)
# Requirement already satisfied: whitebox in /home/hubert/anaconda3/lib/python3.9/site-packages (from whiteboxgui>=0.6.0->geemap) (2.0.3)
# Requirement already satisfied: cffi>=1.0.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from argon2-cffi->notebook<7->nbclassic~=0.2->jupyterlab>=3->geemap) (1.14.6)
# Requirement already satisfied: pycparser in /home/hubert/anaconda3/lib/python3.9/site-packages (from cffi>=1.0.0->argon2-cffi->notebook<7->nbclassic~=0.2->jupyterlab>=3->geemap) (2.20)
# Requirement already satisfied: ratelim in /home/hubert/anaconda3/lib/python3.9/site-packages (from geocoder->geemap) (0.1.6)
# Requirement already satisfied: google-cloud-core<3.0dev,>=1.6.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from google-cloud-storage->earthengine-api>=0.1.230->geemap) (2.2.1)
# Requirement already satisfied: google-resumable-media<3.0dev,>=1.3.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from google-cloud-storage->earthengine-api>=0.1.230->geemap) (2.1.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from google-resumable-media<3.0dev,>=1.3.0->google-cloud-storage->earthengine-api>=0.1.230->geemap) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/hubert/anaconda3/lib/python3.9/site-packages (from matplotlib->geemap) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/hubert/anaconda3/lib/python3.9/site-packages (from matplotlib->geemap) (1.3.1)
# Requirement already satisfied: bleach in /home/hubert/anaconda3/lib/python3.9/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3->geemap) (4.0.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3->geemap) (0.5.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/hubert/anaconda3/lib/python3.9/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3->geemap) (1.4.3)
# Requirement already satisfied: testpath in /home/hubert/anaconda3/lib/python3.9/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3->geemap) (0.5.0)
# Requirement already satisfied: jupyterlab-pygments in /home/hubert/anaconda3/lib/python3.9/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3->geemap) (0.1.2)
# Requirement already satisfied: defusedxml in /home/hubert/anaconda3/lib/python3.9/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3->geemap) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/hubert/anaconda3/lib/python3.9/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3->geemap) (0.8.4)
# Requirement already satisfied: async-generator in /home/hubert/anaconda3/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter-server~=1.4->jupyterlab>=3->geemap) (1.10)
# Requirement already satisfied: nest-asyncio in /home/hubert/anaconda3/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter-server~=1.4->jupyterlab>=3->geemap) (1.5.1)
# Requirement already satisfied: webencodings in /home/hubert/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert->jupyter-server~=1.4->jupyterlab>=3->geemap) (0.5.1)
# Requirement already satisfied: pyyaml in /home/hubert/anaconda3/lib/python3.9/site-packages (from owslib->geemap) (6.0)
# Requirement already satisfied: pyproj>=2 in /home/hubert/anaconda3/lib/python3.9/site-packages (from owslib->geemap) (3.3.0)
# Requirement already satisfied: plotly>=5.2.2 in /home/hubert/anaconda3/lib/python3.9/site-packages (from sankee->geemap) (5.4.0)
# Requirement already satisfied: tenacity>=6.2.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from plotly>=5.2.2->sankee->geemap) (8.0.1)
# Requirement already satisfied: websockets>=9.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from voila->geemap) (10.1)
# Requirement already satisfied: ipygee in /home/hubert/anaconda3/lib/python3.9/site-packages (0.0.17)
# Requirement already satisfied: pandas in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipygee) (1.3.4)
# Requirement already satisfied: geetools in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipygee) (0.6.14)
# Requirement already satisfied: pygal in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipygee) (3.0.0)
# Requirement already satisfied: ipyleaflet>=0.10.2 in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipygee) (0.14.0)
# Requirement already satisfied: ipywidgets<8,>=7.6.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipyleaflet>=0.10.2->ipygee) (7.6.5)
# Requirement already satisfied: traittypes<3,>=0.2.1 in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipyleaflet>=0.10.2->ipygee) (0.2.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (5.1.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (3.5.1)
# Requirement already satisfied: ipython>=4.0.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (7.29.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (6.4.1)
# Requirement already satisfied: nbformat>=4.2.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (5.1.3)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (1.0.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (1.4.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (0.1.2)
# Requirement already satisfied: jupyter-client<8.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (6.1.12)
# Requirement already satisfied: tornado<7.0,>=4.2 in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (6.1)
# Requirement already satisfied: backcall in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (0.2.0)
# Requirement already satisfied: decorator in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (5.1.0)
# Requirement already satisfied: pickleshare in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (3.0.20)
# Requirement already satisfied: jedi>=0.16 in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (0.18.0)
# Requirement already satisfied: pygments in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (2.10.0)
# Requirement already satisfied: setuptools>=18.5 in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (58.0.4)
# Requirement already satisfied: pexpect>4.3 in /home/hubert/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (0.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (4.8.1)
# Requirement already satisfied: pyzmq>=13 in /home/hubert/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (22.2.1)
# Requirement already satisfied: python-dateutil>=2.1 in /home/hubert/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (2.8.2)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /home/hubert/anaconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (0.18.0)
# Requirement already satisfied: six>=1.11.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (1.16.0)
# Requirement already satisfied: attrs>=17.4.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (21.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/hubert/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (0.7.0)
# Requirement already satisfied: wcwidth in /home/hubert/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /home/hubert/anaconda3/lib/python3.9/site-packages (from widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (6.4.5)
# Requirement already satisfied: nbconvert in /home/hubert/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (6.1.0)
# Requirement already satisfied: argon2-cffi in /home/hubert/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (20.1.0)
# Requirement already satisfied: jinja2 in /home/hubert/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (2.11.3)
# Requirement already satisfied: Send2Trash>=1.5.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (1.8.0)
# Requirement already satisfied: prometheus-client in /home/hubert/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (0.11.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/hubert/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (0.9.4)
# Requirement already satisfied: cffi>=1.0.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (1.14.6)
# Requirement already satisfied: pycparser in /home/hubert/anaconda3/lib/python3.9/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (2.20)
# Requirement already satisfied: pyshp in /home/hubert/anaconda3/lib/python3.9/site-packages (from geetools->ipygee) (2.1.3)
# Requirement already satisfied: requests in /home/hubert/anaconda3/lib/python3.9/site-packages (from geetools->ipygee) (2.26.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/hubert/anaconda3/lib/python3.9/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (1.1.1)
# Requirement already satisfied: bleach in /home/hubert/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (4.0.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (0.5.3)
# Requirement already satisfied: defusedxml in /home/hubert/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (0.7.1)
# Requirement already satisfied: testpath in /home/hubert/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (0.5.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /home/hubert/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (0.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/hubert/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/hubert/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (1.4.3)
# Requirement already satisfied: jupyterlab-pygments in /home/hubert/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (0.1.2)
# Requirement already satisfied: nest-asyncio in /home/hubert/anaconda3/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (1.5.1)
# Requirement already satisfied: async-generator in /home/hubert/anaconda3/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (1.10)
# Requirement already satisfied: packaging in /home/hubert/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (21.0)
# Requirement already satisfied: webencodings in /home/hubert/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/hubert/anaconda3/lib/python3.9/site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet>=0.10.2->ipygee) (3.0.4)
# Requirement already satisfied: pytz>=2017.3 in /home/hubert/anaconda3/lib/python3.9/site-packages (from pandas->ipygee) (2021.3)
# Requirement already satisfied: numpy>=1.17.3 in /home/hubert/anaconda3/lib/python3.9/site-packages (from pandas->ipygee) (1.20.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/hubert/anaconda3/lib/python3.9/site-packages (from requests->geetools->ipygee) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from requests->geetools->ipygee) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/hubert/anaconda3/lib/python3.9/site-packages (from requests->geetools->ipygee) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/hubert/anaconda3/lib/python3.9/site-packages (from requests->geetools->ipygee) (1.26.7)
# Requirement already satisfied: geopandas in /home/hubert/anaconda3/lib/python3.9/site-packages (0.10.2)
# Requirement already satisfied: pyproj>=2.2.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from geopandas) (3.3.0)
# Requirement already satisfied: pandas>=0.25.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from geopandas) (1.3.4)
# Requirement already satisfied: fiona>=1.8 in /home/hubert/anaconda3/lib/python3.9/site-packages (from geopandas) (1.8.20)
# Requirement already satisfied: shapely>=1.6 in /home/hubert/anaconda3/lib/python3.9/site-packages (from geopandas) (1.8.0)
# Requirement already satisfied: click-plugins>=1.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /home/hubert/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: certifi in /home/hubert/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (2021.10.8)
# Requirement already satisfied: six>=1.7 in /home/hubert/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (1.16.0)
# Requirement already satisfied: munch in /home/hubert/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: setuptools in /home/hubert/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (58.0.4)
# Requirement already satisfied: click>=4.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (8.0.3)
# Requirement already satisfied: attrs>=17 in /home/hubert/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (21.2.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/hubert/anaconda3/lib/python3.9/site-packages (from pandas>=0.25.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /home/hubert/anaconda3/lib/python3.9/site-packages (from pandas>=0.25.0->geopandas) (2021.3)
# Requirement already satisfied: numpy>=1.17.3 in /home/hubert/anaconda3/lib/python3.9/site-packages (from pandas>=0.25.0->geopandas) (1.20.3)
# Requirement already satisfied: js2py in /home/hubert/anaconda3/lib/python3.9/site-packages (0.71)
# Requirement already satisfied: tzlocal>=1.2 in /home/hubert/anaconda3/lib/python3.9/site-packages (from js2py) (4.1)
# Requirement already satisfied: six>=1.10 in /home/hubert/anaconda3/lib/python3.9/site-packages (from js2py) (1.16.0)
# Requirement already satisfied: pyjsparser>=2.5.1 in /home/hubert/anaconda3/lib/python3.9/site-packages (from js2py) (2.7.1)
# Requirement already satisfied: pytz-deprecation-shim in /home/hubert/anaconda3/lib/python3.9/site-packages (from tzlocal>=1.2->js2py) (0.1.0.post0)
# Requirement already satisfied: tzdata in /home/hubert/anaconda3/lib/python3.9/site-packages (from pytz-deprecation-shim->tzlocal>=1.2->js2py) (2021.5)
# Requirement already satisfied: folium in /home/hubert/anaconda3/lib/python3.9/site-packages (0.12.1.post1)
# Requirement already satisfied: requests in /home/hubert/anaconda3/lib/python3.9/site-packages (from folium) (2.26.0)
# Requirement already satisfied: numpy in /home/hubert/anaconda3/lib/python3.9/site-packages (from folium) (1.20.3)
# Requirement already satisfied: jinja2>=2.9 in /home/hubert/anaconda3/lib/python3.9/site-packages (from folium) (2.11.3)
# Requirement already satisfied: branca>=0.3.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from folium) (0.4.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/hubert/anaconda3/lib/python3.9/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/hubert/anaconda3/lib/python3.9/site-packages (from requests->folium) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/hubert/anaconda3/lib/python3.9/site-packages (from requests->folium) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/hubert/anaconda3/lib/python3.9/site-packages (from requests->folium) (1.26.7)
# Requirement already satisfied: rasterio in /home/hubert/anaconda3/lib/python3.9/site-packages (1.2.10)
# Requirement already satisfied: attrs in /home/hubert/anaconda3/lib/python3.9/site-packages (from rasterio) (21.2.0)
# Requirement already satisfied: click-plugins in /home/hubert/anaconda3/lib/python3.9/site-packages (from rasterio) (1.1.1)
# Requirement already satisfied: click>=4.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from rasterio) (8.0.3)
# Requirement already satisfied: snuggs>=1.4.1 in /home/hubert/anaconda3/lib/python3.9/site-packages (from rasterio) (1.4.7)
# Requirement already satisfied: affine in /home/hubert/anaconda3/lib/python3.9/site-packages (from rasterio) (2.3.0)
# Requirement already satisfied: setuptools in /home/hubert/anaconda3/lib/python3.9/site-packages (from rasterio) (58.0.4)
# Requirement already satisfied: numpy in /home/hubert/anaconda3/lib/python3.9/site-packages (from rasterio) (1.20.3)
# Requirement already satisfied: cligj>=0.5 in /home/hubert/anaconda3/lib/python3.9/site-packages (from rasterio) (0.7.2)
# Requirement already satisfied: certifi in /home/hubert/anaconda3/lib/python3.9/site-packages (from rasterio) (2021.10.8)
# Requirement already satisfied: pyparsing>=2.1.6 in /home/hubert/anaconda3/lib/python3.9/site-packages (from snuggs>=1.4.1->rasterio) (3.0.4)
# Requirement already satisfied: tslearn in /home/hubert/anaconda3/lib/python3.9/site-packages (0.5.2)
# Requirement already satisfied: Cython in /home/hubert/anaconda3/lib/python3.9/site-packages (from tslearn) (0.29.24)
# Requirement already satisfied: joblib in /home/hubert/anaconda3/lib/python3.9/site-packages (from tslearn) (1.1.0)
# Requirement already satisfied: scikit-learn in /home/hubert/anaconda3/lib/python3.9/site-packages (from tslearn) (0.24.2)
# Requirement already satisfied: numba in /home/hubert/anaconda3/lib/python3.9/site-packages (from tslearn) (0.54.1)
# Requirement already satisfied: numpy in /home/hubert/anaconda3/lib/python3.9/site-packages (from tslearn) (1.20.3)
# Requirement already satisfied: scipy in /home/hubert/anaconda3/lib/python3.9/site-packages (from tslearn) (1.7.1)
# Requirement already satisfied: setuptools in /home/hubert/anaconda3/lib/python3.9/site-packages (from numba->tslearn) (58.0.4)
# Requirement already satisfied: llvmlite<0.38,>=0.37.0rc1 in /home/hubert/anaconda3/lib/python3.9/site-packages (from numba->tslearn) (0.37.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from scikit-learn->tslearn) (2.2.0)
# Requirement already satisfied: earthengine-api in /home/hubert/anaconda3/lib/python3.9/site-packages (0.1.292)
# Requirement already satisfied: google-auth>=1.4.1 in /home/hubert/anaconda3/lib/python3.9/site-packages (from earthengine-api) (1.35.0)
# Requirement already satisfied: google-api-python-client<2,>=1.12.1 in /home/hubert/anaconda3/lib/python3.9/site-packages (from earthengine-api) (1.12.8)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /home/hubert/anaconda3/lib/python3.9/site-packages (from earthengine-api) (0.1.0)
# Requirement already satisfied: six in /home/hubert/anaconda3/lib/python3.9/site-packages (from earthengine-api) (1.16.0)
# Requirement already satisfied: httplib2shim in /home/hubert/anaconda3/lib/python3.9/site-packages (from earthengine-api) (0.0.3)
# Requirement already satisfied: google-cloud-storage in /home/hubert/anaconda3/lib/python3.9/site-packages (from earthengine-api) (1.43.0)
# Requirement already satisfied: future in /home/hubert/anaconda3/lib/python3.9/site-packages (from earthengine-api) (0.18.2)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /home/hubert/anaconda3/lib/python3.9/site-packages (from earthengine-api) (0.20.2)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from google-api-python-client<2,>=1.12.1->earthengine-api) (3.0.1)
# Requirement already satisfied: google-api-core<2dev,>=1.21.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from google-api-python-client<2,>=1.12.1->earthengine-api) (1.31.4)
# Requirement already satisfied: setuptools>=40.3.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api) (58.0.4)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api) (1.54.0)
# Requirement already satisfied: pytz in /home/hubert/anaconda3/lib/python3.9/site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api) (2021.3)
# Requirement already satisfied: packaging>=14.3 in /home/hubert/anaconda3/lib/python3.9/site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api) (21.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api) (2.26.0)
# Requirement already satisfied: protobuf>=3.12.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api) (3.19.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from google-auth>=1.4.1->earthengine-api) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/hubert/anaconda3/lib/python3.9/site-packages (from google-auth>=1.4.1->earthengine-api) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/hubert/anaconda3/lib/python3.9/site-packages (from google-auth>=1.4.1->earthengine-api) (4.8)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /home/hubert/anaconda3/lib/python3.9/site-packages (from httplib2<1dev,>=0.9.2->earthengine-api) (3.0.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/hubert/anaconda3/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/hubert/anaconda3/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/hubert/anaconda3/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/hubert/anaconda3/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api) (2.0.4)
# Requirement already satisfied: google-cloud-core<3.0dev,>=1.6.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from google-cloud-storage->earthengine-api) (2.2.1)
# Requirement already satisfied: google-resumable-media<3.0dev,>=1.3.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from google-cloud-storage->earthengine-api) (2.1.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /home/hubert/anaconda3/lib/python3.9/site-packages (from google-resumable-media<3.0dev,>=1.3.0->google-cloud-storage->earthengine-api) (1.3.0)

# %%
"""
Created on Nov 2 at Manobi Africa Dakar 16:34:42 2021

@authors: Pierre C. Traore - ICRISAT/ Manobi Africa
          Steven Ndung'u - ICRISAT/ Manobi Africa
          Hubert Kanyamahanga - ICRISAT/ Manobi Africa
          Glorie Wowo - - ICRISAT/ Manobi Africa
"""
################################################################################
########################### Introduction  ######################################
################################################################################

'''
This notebook shows you how to perform supervised classification.The Classifier 
package handles supervised classification using Earth Engine resources. 
The general workflow for classification is:
'''
#####0. Environment Setup
#####1. Collect training data. Assemble features which have a property that 
#######stores the known class label and properties storing numeric values for the predictors.
#####2. Instantiate a classifier. Set its parameters if necessary.
#####3. Train the classifier using the training data.
#####4. Classify an image or feature collection.
#####5. Estimate classification errors with independent validation data.
#####6. Generate raster products from of aoi given date windows
#####7. Generate estimated pixel areas per class classified

################################################################################
####################### Install and load packages ##############################
################################################################################

''' if you are working with Colab, this packages will require to be installed every time the 
script is run. If runnning from a local machine this can be commented out/deleted
'''
# # Installs geemap package
# !pip install geemap
# !pip install ipygee
# !pip install geopandas
# !pip install js2py
# !pip install folium
# !pip install rasterio
# !pip install tslearn
# !pip install earthengine-api

# Import os packages
import os, ee, json, subprocess
import ipygee as ui
import geemap
from os import path as op
from datetime import datetime

#Pandas modules to interact with spatial data
import geopandas as gpd
import pandas as pd
from geopandas import GeoDataFrame
from shapely.geometry import Point,Polygon

#import numpy
import numpy as np
from functools import reduce

################################################################################
################## Authenticate/Setup GEE, GDRIVE, WP #########################
################################################################################
# %cd '/home/hubert/Desktop'
output_path = "/home/hubert/Desktop/Results"

# Make sure that folder exists
if (not op.isdir(output_path)):
  os.makedirs(output_path)
# Login into GEE
ee.Authenticate()
ee.Initialize()

#set up your working paths

# Change the file paths to match the file locations in your Gee project.

study_site_path = "projects/ee-hubertkanye/assets/UpperLowerDeltaMerged"
crop_noncrop = "projects/ee-hubertkanye/assets/crop_noncrop_new"

dpath_root = os.path.dirname(os.path.join(os.path.realpath('__file__')))


# def shp2geojson(dpath, fname):
#     gpd.read_file(os.path.join(dpath, f'{fname}.shp')).to_file(os.path.join(dpath, f'{fname}.geojson'), driver='GeoJSON')

# shp2geojson(os.path.join(dpath_root, 'crop-noncrop-2021.12.03', 'Studysite'), 'UpperLowerDeltaMerged')
# shp2geojson(os.path.join(dpath_root, 'crop-noncrop-2021.12.03', 'crop_noncrop_updated'), 'crop_noncrop_training_set_representative_28112021')

# with open(os.path.join(dpath_root, 'crop-noncrop-2021.12.03', 'Studysite', 'UpperLowerDeltaMerged.geojson')) as f:
#     geojson_studysite = json.load(f)

# with open(os.path.join(dpath_root, 'crop-noncrop-2021.12.03', 'crop_noncrop_updated', 'crop_noncrop_training_set_representative_28112021.geojson')) as f:
#     geojson_crop_noncrop = json.load(f)


# studysite, crop_noncrop = load_data(geojson_studysite, geojson_crop_noncrop)


# Select the start and end date of the time series of interest:
start_date = "2020-02-01"
end_date = "2020-06-30"
# Output directory
out_dir = os.path.join(os.path.expanduser("~"), output_path)

################################################################################
####################### Model Building & Preprocessing #########################
################################################################################

# Create an interactive map
#Map = geemap.Map()

# Function to mask clouds S2
def mask_cloud_and_shadows(image):
    quality_band = image.select("QA60")
    cloudmask = 1 << 10
    cirrusmask = 1 << 11
    mask = quality_band.bitwiseAnd(cloudmask).eq(0) and (
        quality_band.bitwiseAnd(cirrusmask).eq(0)
    )
    return image.updateMask(mask).divide(10000)


# Function to calculate vegetative indices layers, additional feature
#to enrich the classification product.

def add_indices(image):
    #selected indices: other veg indices of interest can be added
    ndbi = image.normalizedDifference(["B11", "B8"]).rename(["ndbi"])
    ndvi = image.normalizedDifference(["B8", "B4"]).rename(["ndvi"])
    mndwi = image.normalizedDifference(["B3", "B11"]).rename(["mndwi"])
    bsi = image.expression(
        "(( X + Y ) - (A + B)) /(( X + Y ) + (A + B)) ",
        {
            "X": image.select("B11"),  # swir1
            "Y": image.select("B4"),  # red
            "A": image.select("B8"),  # nir
            "B": image.select("B2"),  # blue
        },
    ).rename("bsi")
    return image.addBands(ndbi).addBands(ndvi).addBands(mndwi).addBands(bsi)

def load_data(study_site_path, crop_noncrop):
    # 1 Load SENTINEL-2 IMAGE COLLECTION
    sent2 = ee.ImageCollection("COPERNICUS/S2_SR")
    # 2 Load file that covers the Upper delta region of the SRV
    studysite = ee.FeatureCollection(study_site_path)
    # 3 Load our training datasets that containts crop and non crop geometry
    crop_noncrop = ee.FeatureCollection(crop_noncrop)
    return studysite, crop_noncrop


def get_composite(start_date, end_date, studysite):
    """Returns the composite"""
    # 4 Add our area of interest to the Map
    #Map.addLayer(studysite.geometry(), {}, "Area of Interest")

    # We will now search for Sentinel 2 imagery, a multispectral satellite
    # with ~10m resolution and repeat coverage every 5 days.
    # Filters will include selecting bands, a date range, and only imagery within a defined Area of Interest (AOI).

    filtered = (
        ee.ImageCollection("COPERNICUS/S2_SR")
        .filterDate(start_date, end_date)
        .filterMetadata("CLOUDY_PIXEL_PERCENTAGE", "less_than", 20)
        .map(mask_cloud_and_shadows)
        .filter(ee.Filter.bounds(studysite.geometry()))
    ).select("B.*", "SCL")
    # Input imagery is a cloud-free Sentinel_2 composite.
    composite = filtered.median().clip(studysite)
    # Append the vegetative indices layers to the composite
    composite = add_indices(composite)
    #Map.addLayer(composite, {"bands": ["B4", "B3", "B2"]}, "filtered_composite")
   # Map.addLayer(crop_noncrop.geometry())
    return composite


def get_class_labels(crop_noncrop):
    """Returns the class labels"""

    crop = crop_noncrop.filter(ee.Filter.eq("landcover", 1))
    noncrop = crop_noncrop.filter(ee.Filter.eq("landcover", 2))
    # Combine the manually trained data of the crops into a reference dataset*/
    class_labels = crop.merge(noncrop)
    # Add our classes to the Map
    #Map.addLayer(class_labels)
    return class_labels


def train_test_split(composite, class_labels):
    """Returns the both the training and testing partitions"""

    # Overlay the point on the image to get training data.
    training = composite.sampleRegions(
        **{"collection": class_labels, "properties": ["landcover"], "scale": 70}
    )
    # random uniforms to the training dataset.
    withRandom = training.randomColumn()

    # We want to reserve some of the data for testing, to avoid overfitting the model.
    split = 0.7  # Roughly 70% training, 30% testing.
    trainingPartition = withRandom.filter(ee.Filter.lt("random", split))
    testingPartition = withRandom.filter(ee.Filter.gte("random", split))
    return trainingPartition, testingPartition

# Define some variables to be used for model training and validation
studysite, crop_noncrop = load_data(study_site_path, crop_noncrop)
composite = get_composite(start_date, end_date, studysite)
class_labels = get_class_labels(crop_noncrop)
train_data, test_data = train_test_split(composite, get_class_labels(crop_noncrop))


def train_the_classifier(params, model, train_data):
    """Returns the classifier model"""

    label = "landcover"
    # Training the classifier: model = smileRandomForest
    classifier = (
        model(**params)
        .setOutputMode("CLASSIFICATION")
        .train(train_data, label, composite.bandNames())
    )
    # Create an RF classifier with custom parameters
    return classifier


def perform_classification(composite):
    # Classify the image.
    classified = composite.classify(
        train_the_classifier(
            rf_init_params, ee.Classifier.smileRandomForest, train_data
        )
    )
    sld_intervals_crop = (
        "<RasterSymbolizer>"
        + '<ColorMap type="intervals" extended="false">'
        + '<ColorMapEntry color="#10d22c" quantity="1" label="Crop"/>'
        + '<ColorMapEntry color="#000000" quantity="2" label="Non Crop"/>'
        + "</ColorMap>"
        + "</RasterSymbolizer>"
    )
    # Add the classified image to the Map
   # Map.addLayer(classified.sldStyle(sld_intervals_crop), {}, "RF Classified Layer")
    # Map.addLayer(classified, {"min": 0, max:3, "palette": ['#37d615', '#3223d6']}, 'RF_classified')
    return classified

# Set initial params for RF classifier
rf_init_params = {
    "numberOfTrees": 150,  # the number of individual decision tree models
    "variablesPerSplit": None,  # the number of features to use per split
    "minLeafPopulation": 1,  # smallest sample size possible per leaf
    "bagFraction": 0.5,  # fraction of data to include for each individual tree model
    "maxNodes": None,  # max number of leafs/nodes per tree
    "seed": 34,
}  # random seed for "random" choices like sampling. Setting this allows others to 
   # reproduce your exact results even with stochastic parameters


# Define the classifier and the classified 
classifier = train_the_classifier(
    rf_init_params, ee.Classifier.smileRandomForest, train_data
)

classified = perform_classification(composite)

################################################################################
############################ Model Evaluation ##################################
################################################################################


def test_the_classifier(classifier, test_data):
    """Returns the confusion matrix"""

    # test_data:  testingPartition
    test = test_data.classify(classifier)
    # Get a confusion matrix representing expected accuracy.
    rf_confusionMatrix = test.errorMatrix("landcover", "classification")
    return rf_confusionMatrix


rf_confusionMatrix = test_the_classifier(classifier, test_data)

# 5. Accuracy Assessment

# More statistics
headers = [
    "Accuracy",
    "Precision",
    "Recall",
    "Specificity",
    "F1-score",
    "Kappa statistic",
]

metrics = []

def compute_metrics(conf_matr):
    """Returns a list of six computed metrics"""

    y = np.array(
        [
            [conf_matr.getInfo()[1][1], conf_matr.getInfo()[1][2]],
            [conf_matr.getInfo()[2][1], conf_matr.getInfo()[2][2]],
        ]
    )
    cm = np.asmatrix(y)
    accurracy = conf_matr.accuracy().getInfo()
    metrics.append(accurracy)
    precision = cm[0, 0] / (cm[0, 0] + cm[1, 0])
    metrics.append(precision)
    recall = cm[0, 0] / (cm[0, 0] + cm[0, 1])
    metrics.append(recall)
    specificity = cm[1, 1] / (cm[1, 0] + cm[1, 1])
    metrics.append(specificity)
    f1 = 2 * (precision * recall) / (precision + recall)
    metrics.append(f1)
    kappa = conf_matr.kappa().getInfo()
    metrics.append(kappa)
    return metrics


data = compute_metrics(test_the_classifier(classifier, test_data))
rf_acc_ass = pd.DataFrame(data=[data], columns=headers)
print(f"Random Forest:\n{rf_acc_ass.head()}\n")

################################################################################
######################### Model Outputs/Exports ################################
################################################################################


def export_accurracy_assessment(out_dir, data, header):
    """Exports the metrics as a csv file to the provided output path"""
    accurracy_assessment = os.path.join(out_dir, "accurracy_assessment.json")
    data = dict(zip(header, data))
    with open(accurracy_assessment, 'w') as outfile:
        json.dump(data, outfile)

def export_classified_tiff(classified, studysite,start_date,end_date):
    """Export the image, specifying scale and region."""
    # Warning, This specific export takes at least 1 hour, and 700+ MB
    # GEE folder does not use a path, it uses a unique name to find the export location

    now = datetime.now()  # current date and time
    time =  now.strftime("%m%d%Y_%H%M")
    # We will save it to Google Drive for later reuse
    raster_name = op.join(out_dir, "crop_noncrop_classification_{}_to_{}_{}".format(start_date,end_date,str(time)))
    task = ee.batch.Export.image.toDrive(
        **{
            "image": classified,
            "description": "crop_noncrop_classification_{}_to_{}_{}".format(start_date,end_date,str(time)),
            "folder": op.basename(output_path),
            "scale": 10,
            "fileNamePrefix": raster_name.split('/')[-1],
            "region": studysite.geometry(),
            "fileFormat": "GeoTIFF",
            "formatOptions": {"cloudOptimized": "true"},
            "maxPixels": 1e12,
        }
    )
    # This task will run in the background even if you close this notebook.
    # You can also check on the status of the task through the Javascript GEE interface
    # https://code.earthengine.google.com
    return task.start()



def download_classified_tiff(classified, studysite,start_date,end_date):
    """Export and download the image, specifying scale and region."""
    now = datetime.now()  # current date and time
    time =  now.strftime("%m%d%Y_%H%M")
    # The image will be saved in your local folder
    filename = op.join(out_dir, "crop_noncrop_classification_{}_to_{}_{}{}".format(start_date,end_date,str(time), '.tif'))
    geemap.ee_export_image(classified, filename=filename, scale=90, region=studysite.geometry(), file_per_band=False)


################################################################################
################### Area calculations (Pixel Based) ############################
################################################################################

# Class Area calculation

def get_item(item):
  areaDict = ee.Dictionary(item)
  classNumber = ee.Number(areaDict.get('classification')).format()
  # The result will be in square meters, this converts them into square kilometers 
  area = ee.Number(areaDict.get('sum')).divide(1e6).round()
  return ee.List([classNumber, area])

def classAreaLists(class_areas):
  return class_areas.map(get_item) 

def export_class_area(classified):
  areaImage = ee.Image.pixelArea().addBands(classified)
  areas = areaImage.reduceRegion(**{ 
      "reducer": ee.Reducer.sum().group(**{
              "groupField": 1,
              "groupName": "classification",
      }),
      "geometry": studysite.geometry(),
      "scale": 10, 
      "maxPixels": 1e9
      })
  class_areas = ee.List(areas.get("groups"))
  # Flattens said dictionary so it is readable for us
  result = ee.Dictionary(classAreaLists(class_areas).flatten()) 
  now = datetime.now()  # current date and time
  time =  now.strftime("%m%d%Y_%H%M")
  class_area = os.path.join(out_dir, "class_area_{}.json".format(time))
  serialized_data = result.getInfo()
  now = datetime.now()  # current date and time
  time =  now.strftime("%m%d%Y%H%M%S")
  data = {}
  data["Cropped Area"] = serialized_data["1"] * 100 #ha
  data["Non Cropped Area"] = serialized_data["2"]  * 100 #ha
  print(f"Covered Areas(ha):\n{data}\n")
  with open(class_area, 'w') as outfile:
      json.dump(data, outfile)
  return serialized_data

export_class_area(classified)
# Call the functions

export_accurracy_assessment(out_dir, data, headers)
#export_class_area(classified)
#export_classified_tiff(classified, studysite,start_date,end_date)


################################################################################
################################# Predictions ##################################
################################################################################

'''
Here, we want to generate a new product provided new windows for the following year. 
The model above has been trained using images sampled from 2020, we now can use the 
model to predict outputs  for 2021. 
'''
# Create a new window

################################################################################
############################# 2021 Prediction 1 ################################
################################################################################

start_date_new = "2021-02-15"
end_date_new = "2021-03-27"
pred_comp = get_composite(start_date_new, end_date_new, studysite)
print('Prediction between: 15 FEB - 27 MAR')
pred_comp = perform_classification(pred_comp)
export_class_area(pred_comp)
export_classified_tiff(pred_comp, studysite,start_date_new, end_date_new)
download_classified_tiff(pred_comp, studysite,start_date_new, end_date_new)

################################################################################
############################# 2021 Prediction 2 ################################
################################################################################

start_date_new = "2021-04-01"
end_date_new = "2021-05-30"
pred_comp1 = get_composite(start_date_new, end_date_new, studysite)
print('Prediction between: 01 APR - 30 MAY')
pred_comp1 = perform_classification(pred_comp1)
export_class_area(pred_comp1)
export_classified_tiff(pred_comp1, studysite,start_date_new, end_date_new)
download_classified_tiff(pred_comp1, studysite,start_date_new, end_date_new)

################################################################################
############################# 2021 Prediction 3 ################################
################################################################################

start_date_new = "2021-02-01"
end_date_new = "2021-06-30"
pred_comp1 = get_composite(start_date_new, end_date_new, studysite)
print('Prediction between: FEB - June')
pred_comp1 = perform_classification(pred_comp1)
export_class_area(pred_comp1)
export_classified_tiff(pred_comp1, studysite,start_date_new, end_date_new)
download_classified_tiff(pred_comp1, studysite,start_date_new, end_date_new)
# Out:
# /home/hubert/Desktop
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://accounts.google.com/o/oauth2/auth?client_id=517222506229-vsmmajv00ul0bs7p89v5m89qs8eb9359.apps.googleusercontent.com&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fearthengine+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.full_control&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&response_type=code&code_challenge=PT7GTNFi1LvXJ132cR5tcKBhF_sPqzcasjGEOC-FAm0&code_challenge_method=S256>https://accounts.google.com/o/oauth2/auth?client_id=517222506229-vsmmajv00ul0bs7p89v5m89qs8eb9359.apps.googleusercontent.com&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fearthengine+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.full_control&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&response_type=code&code_challenge=PT7GTNFi1LvXJ132cR5tcKBhF_sPqzcasjGEOC-FAm0&code_challenge_method=S256</a></p>
#         <p>The authorization workflow will generate a code, which you
#         should paste in the box below</p>
# Enter verification code: 4/1AX4XfWgGcweSkRIHKcKrKEB23AssR7aSCsta-zd0eDq26hyZYE3SqnZRJ54
#
# Successfully saved authorization token.
# Random Forest:
#    Accuracy  Precision    Recall  Specificity  F1-score  Kappa statistic
# 0  0.909761   0.843109  0.754593     0.957131  0.796399         0.738662
#
# Covered Areas(ha):
# {'Cropped Area': 45900, 'Non Cropped Area': 217900}
#
# Prediction between: 15 FEB - 27 MAR
# Covered Areas(ha):
# {'Cropped Area': 22100, 'Non Cropped Area': 241700}
#
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/70caa7ddd7124de4e9448c431e0e8a7b-b49b5393003969dd251d4ccc028dbdd3:getPixels
# Please wait ...
# Data downloaded to /home/hubert/Desktop/Results/crop_noncrop_classification_2021-02-15_to_2021-03-27_12132021_1040.tif
# Prediction between: 01 APR - 30 MAY
# Covered Areas(ha):
# {'Cropped Area': 30900, 'Non Cropped Area': 233000}
#
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/6dbf4a9ae888bda79b6f6293073e5c4f-4a3343375fd3fde8917a7f3215522f42:getPixels
# Please wait ...
# Data downloaded to /home/hubert/Desktop/Results/crop_noncrop_classification_2021-04-01_to_2021-05-30_12132021_1041.tif
# Prediction between: FEB - June
# Covered Areas(ha):
# {'Cropped Area': 33400, 'Non Cropped Area': 230400}
#
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/2e456ac72749cee4e92ebcfd100cff2d-5d36caafb76422918d0c638274e5ebc8:getPixels
# Please wait ...
# Data downloaded to /home/hubert/Desktop/Results/crop_noncrop_classification_2021-02-01_to_2021-06-30_12132021_1042.tif
